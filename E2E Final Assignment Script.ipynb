# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine
# !pip install pymysql
# !pip install cryptography

# %% [markdown]
# ## Connecting to SQL Instance

# %%
MYSQL_HOSTNAME = '20.119.65.43'
MYSQL_USER = 'DBA'
MYSQL_PASSWORD = 'ahi2021'
MYSQL_DATABASE = 'e2e'

# %%
connection_string = f'mysql+pymysql://{MYSQL_USER}:{MYSQL_PASSWORD}@{MYSQL_HOSTNAME}:3306/{MYSQL_DATABASE}'
engine = create_engine(connection_string)

# %%
connection_string
# Out:
# 'mysql+pymysql://DBA:ahi2021@20.119.65.43:3306/e2e'

# %%
csvfile = pd.read_csv('https://raw.githubusercontent.com/KallistaT/HHA504-E2E-Final-Assignment/main/H1N1_Flu_Vaccines.csv')

# %%
csvfile
# Out:
#        respondent_id  h1n1_concern  h1n1_knowledge  behavioral_antiviral_meds  \
# 0                  0           1.0             0.0                        0.0
# 1                  1           3.0             2.0                        0.0
# 2                  2           1.0             1.0                        0.0
# 3                  3           1.0             1.0                        0.0
# 4                  4           2.0             1.0                        0.0
# ...              ...           ...             ...                        ...
# 26702          26702           2.0             0.0                        0.0
# 26703          26703           1.0             2.0                        0.0
# 26704          26704           2.0             2.0                        0.0
# 26705          26705           1.0             1.0                        0.0
# 26706          26706           0.0             0.0                        0.0
#
# ...

# %% [markdown]
# ## Uploading CSV to MySQL Database

# %%
TABLENAME = 'H1N1'

# %%
csvfile.to_sql(TABLENAME, con=engine, if_exists='append')
